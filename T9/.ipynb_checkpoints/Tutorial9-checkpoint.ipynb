# %% [markdown]
# **Name:** LIXINYAN
#
# **EID:** 55670594

# %% [markdown]
# # CS5489 - Tutorial 9
# ## Face Detection with CNNs
#
# In the previous tutorial, you used an MLP to detect a face in a small image patch.
# In this tutorial you will train a CNN instead of an MLP.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch
random.seed(100)
import skimage.io
import skimage.color
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
# use TensorFlow backend
# %env KERAS_BACKEND=tensorflow     
import keras
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, Flatten, Input
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import struct

# use keras backend (K) to force channels-first ordering
K.set_image_data_format('channels_first')
# Out:
# env: KERAS_BACKEND=tensorflow
# Using TensorFlow backend.
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train':[], 'test':[]}
classes = {'train':[], 'test':[]}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):
        
        # filename is : faces/train/face/fname.png
        (fdir1, fname)  = os.path.split(name)     # get file name
        (fdir2, fclass) = os.path.split(fdir1) # get class (face, nonface)
        (fdir3, fset)   = os.path.split(fdir2) # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")  

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1
            
        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            #img = matplotlib.image.imread(myfile)
            img = skimage.io.imread(myfile)
            # convert to grayscale
            img = skimage.color.rgb2gray(img)
            myfile.close()
            
            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

        
zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY  = asarray(classes['test'])

# convert class labels to binary indicators
trainYb = keras.utils.np_utils.to_categorical(trainY)
testYb  = keras.utils.np_utils.to_categorical(testY)

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977,1,19,19))
testI  = asarray(imgdata['test']).reshape((944,1,19,19))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb  = testYb[inds2]
trainY = trainY[inds1]
testY  = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# (6977, 1, 19, 19)
# (944, 1, 19, 19)

# %% [markdown]
# Each image is a 1x19x19 array of pixel values.  The first dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1,2,1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1,2,2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)
    
    # create a list of images (reshape if necessary)
    for i in range(0,numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))
    
    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5*(X[0].max()+X[0].min())
        for i in range(0,leftover):
            tmp.append(ones(tmp[0].shape)*meanimg)
    
    # make the montage
    tmp2 = []
    for i in range(0,len(tmp),maxw):
        tmp2.append( hstack(tmp[i:i+maxw]) )
    montimg = vstack(tmp2) 
    return montimg

# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W,cmap='gray', interpolation='nearest')  
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])
            
            if ((highlight_green is not None) and highlight_green[idx]) or \
               ((highlight_red is not None) and highlight_red[idx]): 
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')               
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()

# show a few images
plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,0]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,1]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = \
  model_selection.train_test_split(trainI, trainYb, 
  train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 1, 19, 19)
# (698, 1, 19, 19)

# %% [markdown]
# Here are some useful functions.

# %%
def plot_history(history): 
    fig, ax1 = plt.subplots()
    
    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--', label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)    
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    if 'acc' in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history['acc'], 'b', label="training acc ({:.4f})".format(history.history['acc'][-1]))
        ax2.plot(history.history['val_acc'], 'b--', label="validation acc ({:.4f})".format(history.history['val_acc'][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')        
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tensorflow.set_random_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(1,19,19)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_acc',             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /opt/anaconda3/lib/python3.7/site-packages/keras/callbacks/callbacks.py:846: RuntimeWarning: Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# test accuracy: 0.5603813559322034

# %% [markdown]
# ## 2. Detection using CNN
#
# Train an CNN to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainY` as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping, regularization, etc. to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
# use the given nn structure 
# learning rates = 1e-2
# batch_size = 50
# acc = 0.619

random.seed(4487); 
tensorflow.set_random_seed(4487)

 # build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),strides=(2,2), activation='relu', padding='same', input_shape=(1,19,19)))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
              
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')
callbacks_list = [earlystop]
                         
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy, 
           optimizer=keras.optimizers.SGD(lr=1e-2, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])
                         
history = nn.fit(vtrainI, vtrainYb, epochs=100, 
                 batch_size=50, callbacks=callbacks_list,
                 validation_data=validsetI, verbose=False)
# Out:
# Epoch 00042: early stopping

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 10, 10, 10)        260
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                50050
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 50,412
# Trainable params: 50,412
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.6197033898305084

# %%
# use the given nn structure 
# learning rates = 1e-3
# batch_size = 50
# acc = 0.617

random.seed(4487); 
tensorflow.set_random_seed(4487)

 # build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),strides=(2,2), activation='relu', padding='same', input_shape=(1,19,19)))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
              
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')
callbacks_list = [earlystop]
                         
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy, 
           optimizer=keras.optimizers.SGD(lr=1e-3, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])
                         
history = nn.fit(vtrainI, vtrainYb, epochs=100, 
                 batch_size=50, callbacks=callbacks_list,
                 validation_data=validsetI, verbose=False)

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 10, 10, 10)        260
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 50)                50050
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 50,412
# Trainable params: 50,412
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.6175847457627118

# %%
# try a different nn structure with more conv layers
# learning rates = 1e-3
# batch_size = 50
# acc = 0.675

random.seed(4487); 
tensorflow.set_random_seed(4487)

 # build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),strides=(2,2), activation='relu', padding='same', input_shape=(1,19,19)))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
              
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')
callbacks_list = [earlystop]
                         
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy, 
           optimizer=keras.optimizers.SGD(lr=1e-3, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])
                         
history = nn.fit(vtrainI, vtrainYb, epochs=100, 
                 batch_size=50, callbacks=callbacks_list,
                 validation_data=validsetI, verbose=False)
# Out:
# Epoch 00080: early stopping

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 10, 10, 10)        260
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 40, 5, 5)          10040
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 80, 5, 5)          80080
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 2000)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 50)                100050
# _________________________________________________________________
# dense_21 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 190,532
# Trainable params: 190,532
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.6758474576271186

# %%
# try a different nn structure with more conv layers
# learning rates = 1e-2
# batch_size = 50
# acc = 0.627

random.seed(4487); 
tensorflow.set_random_seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2),activation='relu', input_shape=(1,19,19),
              padding='same', data_format='channels_first'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu',
              padding='same', data_format='channels_first'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu',
              padding='same', data_format='channels_first')) 
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
    
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')

callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=1e-2, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])

history = nn.fit(vtrainI, vtrainYb, epochs=100, 
                 batch_size=50, callbacks=callbacks_list,
                 validation_data=validsetI, verbose=False)
# Out:
# Epoch 00021: early stopping

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 10, 10, 10)        260
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 40, 5, 5)          10040
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 80, 5, 5)          80080
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 2000)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 50)                100050
# _________________________________________________________________
# dense_27 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 190,532
# Trainable params: 190,532
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.6271186440677966

# %% [markdown]
# How does the NN compare to the MLP and linear/non-linear classifiers that you tried in Tutorial 4/8?
# 1. By using 2 layer (100 neurons in hidden layer) MLP, the best accuracy on testset is 0.689, traing speed is very fast; By using 3 layer (100/30 neurons in hidden layer1/2) MLP, the accuracy on testset is about 0.6; Poly-SVM in Tutorial got 0.5 acc;
# 2. By using this randomly designed NN, I got acc not less than 0.6;
# 3. However, I think the performance of MLP is more stable;
# 4. NN trained faster (due to less params).

# %% [markdown]
# ## 3. Data Augmentation
#
# Now use data augmentation (introduced in the last tutorial) to try to improve the accuracy.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)

def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1-p, X.shape)

def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0],1,1)
    elif X.ndim == 4:
        dshape = (X.shape[0],1,1,1)
    else:
        dshape = (1,)
    a = random.normal(1,sigma2, dshape)
    b = random.normal(0,alpha2, dshape)
    return minimum(maximum( a*X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_first')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,1,19,19), [1], batch_size=1):
    imgs.append(augimg[0,0,:,:])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead of "fit", we now  use the "fit_generator" method, which will pass each input through the ImageDataGenerator before sending it to the MLP.  We also disable early stopping so that the training sees more augmented data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tensorflow.set_random_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(1,19,19)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_acc',             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=100,
#           callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)
# Out:
# Epoch 1/100
# 126/125 [==============================] - 1s 11ms/step - loss: 0.2575 - accuracy: 0.8917 - val_loss: 0.1138 - val_accuracy: 0.9527
# Epoch 2/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.1835 - accuracy: 0.9237 - val_loss: 0.1178 - val_accuracy: 0.9542
# Epoch 3/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1701 - accuracy: 0.9315 - val_loss: 0.0946 - val_accuracy: 0.9599
# Epoch 4/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.1796 - accuracy: 0.9304 - val_loss: 0.1132 - val_accuracy: 0.9499
# Epoch 5/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1649 - accuracy: 0.9331 - val_loss: 0.1327 - val_accuracy: 0.9456
# Epoch 6/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.1657 - accuracy: 0.9345 - val_loss: 0.1197 - val_accuracy: 0.9527
# Epoch 7/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1699 - accuracy: 0.9339 - val_loss: 0.1017 - val_accuracy: 0.9656
# Epoch 8/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1709 - accuracy: 0.9320 - val_loss: 0.0963 - val_accuracy: 0.9613
# Epoch 9/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1699 - accuracy: 0.9322 - val_loss: 0.1024 - val_accuracy: 0.9556
# Epoch 10/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.1655 - accuracy: 0.9350 - val_loss: 0.0944 - val_accuracy: 0.9599
# Epoch 11/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1651 - accuracy: 0.9334 - val_loss: 0.1290 - val_accuracy: 0.9384
# Epoch 12/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1630 - accuracy: 0.9336 - val_loss: 0.1301 - val_accuracy: 0.9413
# Epoch 13/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.1649 - accuracy: 0.9337 - val_loss: 0.2374 - val_accuracy: 0.9026
# Epoch 14/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1647 - accuracy: 0.9337 - val_loss: 0.1038 - val_accuracy: 0.9499
# Epoch 15/100
# 126/125 [==============================] - 2s 12ms/step - loss: 0.1572 - accuracy: 0.9385 - val_loss: 0.1212 - val_accuracy: 0.9484
# Epoch 16/100
# 126/125 [==============================] - 1s 12ms/step - loss: 0.

acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.6790254237288136

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.622 to 0.755!

# %% [markdown]
# Now train your best CNN from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
# the best model above
# learning rates = 1e-3
# batch_size = 50
# before augment, acc = 0.675
# after augment, acc = 

random.seed(4487); 
tensorflow.set_random_seed(4487)

 # build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),strides=(2,2), activation='relu', padding='same', input_shape=(1,19,19)))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
              
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')
callbacks_list = [earlystop]
                         
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy, 
           optimizer=keras.optimizers.SGD(lr=1e-3, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])
                         
history = nn.fit(vtrainI, vtrainYb, epochs=100, 
                 batch_size=50, callbacks=callbacks_list,
                 validation_data=validsetI, verbose=False)

history = nn.fit_generator(datagen.flow(vtrainI, vtrainYb, batch_size=50),
                           steps_per_epoch=len(vtrainI)/50, epochs=100,
                           callbacks=callbacks_list, 
                           validation_data=validsetI, verbose=True)
# Out:
# Epoch 00080: early stopping
# Epoch 1/100
# 126/125 [==============================] - 4s 28ms/step - loss: 0.1471 - accuracy: 0.9509 - val_loss: 0.0465 - val_accuracy: 0.9842
# Epoch 2/100
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0945 - accuracy: 0.9662 - val_loss: 0.0613 - val_accuracy: 0.9771
# Epoch 3/100
# 126/125 [==============================] - 3s 27ms/step - loss: 0.0977 - accuracy: 0.9635 - val_loss: 0.0647 - val_accuracy: 0.9771
# Epoch 4/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0826 - accuracy: 0.9718 - val_loss: 0.0410 - val_accuracy: 0.9885
# Epoch 5/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0830 - accuracy: 0.9705 - val_loss: 0.0448 - val_accuracy: 0.9871
# Epoch 6/100
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0736 - accuracy: 0.9747 - val_loss: 0.0564 - val_accuracy: 0.9785
# Epoch 7/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0730 - accuracy: 0.9724 - val_loss: 0.0676 - val_accuracy: 0.9713
# Epoch 8/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0708 - accuracy: 0.9775 - val_loss: 0.0350 - val_accuracy: 0.9900
# Epoch 9/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0680 - accuracy: 0.9793 - val_loss: 0.0585 - val_accuracy: 0.9799
# Epoch 10/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0683 - accuracy: 0.9772 - val_loss: 0.0490 - val_accuracy: 0.9857
# Epoch 11/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0647 - accuracy: 0.9801 - val_loss: 0.0367 - val_accuracy: 0.9914
# Epoch 12/100
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0668 - accuracy: 0.9782 - val_loss: 0.0373 - val_accuracy: 0.9900
# Epoch 13/100
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0627 - accuracy: 0.9812 - val_loss: 0.0537 - val_accuracy: 0.9799
# Epoch 00013: early stopping

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_22 (Conv2D)           (None, 10, 10, 10)        260
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 40, 5, 5)          10040
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 80, 5, 5)          80080
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 2000)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 50)                100050
# _________________________________________________________________
# dense_29 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 190,532
# Trainable params: 190,532
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.823093220338983

# %%
# use the given nn structure 
# learning rates = 1e-2
# before augment, acc = 0.675
# after augment, acc = 

random.seed(4487); 
tensorflow.set_random_seed(4487)

 # build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),strides=(2,2), activation='relu', padding='same', input_shape=(1,19,19)))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))
              
# setup early stopping callback function
earlystop = keras.callbacks.EarlyStopping(monitor='val_loss', 
                                          min_delta=0.0001, patience=5, 
                                          verbose=1, mode='auto')
callbacks_list = [earlystop]
                         
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy, 
           optimizer=keras.optimizers.SGD(lr=1e-2, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])

history = nn.fit_generator(datagen.flow(vtrainI, vtrainYb, batch_size=50),
                           steps_per_epoch=len(vtrainI)/50, epochs=100,
                           callbacks=callbacks_list, 
                           validation_data=validsetI, verbose=True)
# Out:
# Epoch 1/100
# 126/125 [==============================] - 2s 17ms/step - loss: 0.2968 - accuracy: 0.8635 - val_loss: 0.1322 - val_accuracy: 0.9484
# Epoch 2/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.1761 - accuracy: 0.9282 - val_loss: 0.0972 - val_accuracy: 0.9656
# Epoch 3/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.1532 - accuracy: 0.9393 - val_loss: 0.0841 - val_accuracy: 0.9670
# Epoch 4/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.1375 - accuracy: 0.9431 - val_loss: 0.0918 - val_accuracy: 0.9628
# Epoch 5/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.1172 - accuracy: 0.9575 - val_loss: 0.0686 - val_accuracy: 0.9699
# Epoch 6/100
# 126/125 [==============================] - 2s 16ms/step - loss: 0.1079 - accuracy: 0.9565 - val_loss: 0.0633 - val_accuracy: 0.9828
# Epoch 7/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0962 - accuracy: 0.9621 - val_loss: 0.0606 - val_accuracy: 0.9728
# Epoch 8/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0874 - accuracy: 0.9669 - val_loss: 0.0612 - val_accuracy: 0.9699
# Epoch 9/100
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0800 - accuracy: 0.9686 - val_loss: 0.0497 - val_accuracy: 0.9785
# Epoch 10/100
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0702 - accuracy: 0.9742 - val_loss: 0.0484 - val_accuracy: 0.9742
# Epoch 11/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0715 - accuracy: 0.9739 - val_loss: 0.0546 - val_accuracy: 0.9699
# Epoch 12/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0619 - accuracy: 0.9769 - val_loss: 0.0564 - val_accuracy: 0.9713
# Epoch 13/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0598 - accuracy: 0.9787 - val_loss: 0.0797 - val_accuracy: 0.9713
# Epoch 14/100
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0604 - accuracy: 0.9777 - val_loss: 0.0284 - val_accuracy: 0.9900
# Epoch 15/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0613 - accuracy: 0.9787 - val_loss: 0.0343 - val_accuracy: 0.9857
# Epoch 16/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0514 - accuracy: 0.9806 - val_loss: 0.0365 - val_accuracy: 0.9828
# Epoch 17/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0461 - accuracy: 0.9842 - val_loss: 0.0242 - val_accuracy: 0.9914
# Epoch 18/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0452 - accuracy: 0.9825 - val_loss: 0.0449 - val_accuracy: 0.9799
# Epoch 19/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0417 - accuracy: 0.9849 - val_loss: 0.0215 - val_accuracy: 0.9885
# Epoch 20/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0431 - accuracy: 0.9852 - val_loss: 0.0322 - val_accuracy: 0.9799
# Epoch 21/100
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0399 - accuracy: 0.9861 - val_loss: 0.0197 - val_accuracy: 0.9943
# Epoch 22/100
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0340 - accuracy: 0.9874 - val_loss: 0.0223 - val_accuracy: 0.9928
# Epoch 23/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0347 - accuracy: 0.9871 - val_loss: 0.0343 - val_accuracy: 0.9842
# Epoch 24/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0330 - accuracy: 0.9869 - val_loss: 0.0406 - val_accuracy: 0.9828
# Epoch 25/100
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0347 - accuracy: 0.9873 - val_loss: 0.0236 - val_accuracy: 0.9900
# Epoch 26/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0306 - accuracy: 0.9885 - val_loss: 0.0170 - val_accuracy: 0.9943
# Epoch 27/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0265 - accuracy: 0.9901 - val_loss: 0.0409 - val_accuracy: 0.9842
# Epoch 28/100
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0316 - accuracy: 0.9881 - val_loss: 0.0255 - val_accuracy: 0.9900
# Epoch 29/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0282 - accuracy: 0.9900 - val_loss: 0.0312 - val_accuracy: 0.9871
# Epoch 30/100
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0247 - accuracy: 0.9920 - val_loss: 0.0101 - val_accuracy: 0.9943
# Epoch 31/100
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0232 - accuracy: 0.9920 - val_loss: 0.0256 - val_accuracy: 0.9885
# Epoch 32/100
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0224 - accuracy: 0.9928 - val_loss: 0.0145 - val_accuracy: 0.9957
# Epoch 33/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0242 - accuracy: 0.9922 - val_loss: 0.0155 - val_accuracy: 0.9928
# Epoch 34/100
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.0212 - val_accuracy: 0.9914
# Epoch 35/100
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 0.0146 - val_accuracy: 0.9943
# Epoch 00035: early stopping

# %%
nn.summary()
plot_history(history)
predY = nn.predict_classes(testI, verbose=False)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 10, 10, 10)        260
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_30 (Dense)             (None, 50)                50050
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 102
# =================================================================
# Total params: 50,412
# Trainable params: 50,412
# Non-trainable params: 0
# _________________________________________________________________
# test accuracy: 0.8040254237288136

# %% [markdown]
# _How does CNN with data augmentation compare with your work in Tutorial 8?_
# 1. Slightly better, I got acc around 0.76 in Tutorial8, but in NN I got around 0.81;
# 2. Also mentioned that the r=training speed is faster;
# 3. In NN, the validation loss is much smaller than that in MLP, maybe this model has a better generalization ability.

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg3 = skimage.io.imread(fname)

# convert to grayscale
testimg = skimage.color.rgb2gray(testimg3)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], 1, psize[2], psize[3]))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 1, 19, 19)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
### YOUR CODE HERE
prednewY = nn.predict_classes(newI)

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg.shape[1]-imgY2.shape[1]))))
    
# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
# 1. Yes, different from the model I trained in Tutorial 4 & 8, here the nn model did not recognize chest label as human face, but it did not recognize some faces;
# 2. The same as the model I trained in Tutorial 4 & 8, the faces in the left of this image did not be recognized, which is very wired.
# 3. NN gives higher accuracy,it will not recognize non-face as face, but it recognize face as non-face.

# %% [markdown]
# - You can try it on your own images.  The faces should all be around 19x19 pixels though.
# - We only used 1/8 of the training data. Try using more data to train it!
